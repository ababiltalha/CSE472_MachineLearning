# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

datadir = "/home/ababil/BUET/4-2/CSE472/Datasets/"
filename = "WA_Fn-UseC_-Telco-Customer-Churn.csv"


df = pd.read_csv(datadir+filename)
# df.info()

# change total charges to numeric
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# if there are NaN values, replace them with 0
for col in df.columns.values:
    if df[col].dtype == 'int64' or df[col].dtype == 'float64':
        df[col] = df[col].fillna(0)

# drop customerID
df.drop(['customerID'], axis=1, inplace=True)

# change the binary columns to 0 and 1
for col in df.columns.values:
    # if object type and only 2 unique values
    if len(df[col].unique()) == 2 and df[col].dtype == 'object':
        # if the first value is 'No' then change it to 0 and the second value to 1
        if df[col].unique()[0] == 'No':
            df[col] = df[col].map({df[col].unique()[0]:0, df[col].unique()[1]:1})
        else:
            df[col] = df[col].map({df[col].unique()[0]:1, df[col].unique()[1]:0})
            
# recognize outliers in monthly charges
for col in df.columns.values:
    if df[col].dtype == 'float64':
        z = np.abs(stats.zscore(df['TotalCharges']))
        threshold = 3
        outliers = np.where(z > threshold)
        if len(outliers[0]) > 0:
            df.drop(outliers[0], inplace=True)

# split into features and labels
features = df[df.columns.values[:-1]]
labels = df[df.columns.values[-1]]

encoded_features = pd.get_dummies(features)
# print(encoded_features.head())

# split into train, validation and test set
X_train, X_test, y_train, y_test = train_test_split(encoded_features, labels, test_size=0.2, random_state=77)   
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=77)

# %%
X_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 544        0              0        0           0      13             0
# 1843       1              0        1           1      71             1
# 3368       1              0        0           0      46             1
# 5035       0              0        0           0      20             1
# 2750       0              0        0           0       3             1
# ...      ...            ...      ...         ...     ...           ...
# 6387       1              0        1           0      35             1
# 4246       0              0        1           1      68             1
# 6499       0              0        0           0       1             1
# 5631       0              0        1           0       3             0
# 3948       1              0        1           1      56             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  MultipleLines_No  ...  \
# 544                  1           45.55        597.00                 0  ...
# 1843                 0           19.70       1415.85                 1  ...
# 3368                 1           94.15       4408.45                 0  ...
# 5035                 0           78.80       1641.30                 1  ...
# 2750                 1           19.45         69.25                 1  ...
# ...                ...             ...           ...               ...  ...
# 6387                 0           56.85       1861.10                 1  ...
# 4246                 1          110.20       7467.50                 0  ...
# 6499                 0           20.30         20.30                 1  ...
# 5631                 0           25.00         78.25                 0  ...
# 3948                 0           88.90       4968.00                 1  ...
#
#       StreamingMovies_No  StreamingMovies_No internet service  \
# 544                    1                                    0
# 1843                   0                                    1
# 3368                   0                                    0
# 5035                   1                                    0
# 2750                   0                                    1
# ...                  ...                                  ...
# 6387                   1                                    0
# 4246                   0                                    0
# 6499                   0                                    1
# 5631                   1                                    0
# 3948                   0                                    0
#
#       StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 544                     0                        1                  0
# 1843                    0                        0                  0
# 3368                    1                        0                  1
# 5035                    0                        1                  0
# 2750                    0                        0                  1
# ...                   ...                      ...                ...
# 6387                    0                        1                  0
# 4246                    1                        0                  0
# 6499                    0                        1                  0
# 5631                    0                        1                  0
# 3948                    1                        0                  1
#
#       Contract_Two year  PaymentMethod_Bank transfer (automatic)  \
# 544                   0                                        0
# 1843                  1                                        0
# 3368                  0                                        0
# 5035                  0                                        0
# 2750                  0                                        0
# ...                 ...                                      ...
# 6387                  0                                        0
# 4246                  1                                        0
# 6499                  0                                        0
# 5631                  0                                        0
# 3948                  0                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 544                                       1                               0
# 1843                                      1                               0
# 3368                                      0                               1
# 5035                                      0                               1
# 2750                                      0                               0
# ...                                     ...                             ...
# 6387                                      0                               1
# 4246                                      0                               1
# 6499                                      0                               0
# 5631                                      0                               0
# 3948                                      0                               0
#
#       PaymentMethod_Mailed check
# 544                            0
# 1843                           0
# 3368                           0
# 5035                           0
# 2750                           1
# ...                          ...
# 6387                           0
# 4246                           0
# 6499                           1
# 5631                           1
# 3948                           0
#
# [4507 rows x 40 columns]

# %%
# scale the features
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns.values)
X_train_scaled_df
# Out:
#         gender  SeniorCitizen   Partner  Dependents    tenure  PhoneService  \
# 0    -1.008243      -0.443219 -0.948728   -0.649090 -0.779915     -2.973317
# 1     0.991824      -0.443219  1.054043    1.540618  1.580098      0.336325
# 2     0.991824      -0.443219 -0.948728   -0.649090  0.562851      0.336325
# 3    -1.008243      -0.443219 -0.948728   -0.649090 -0.495086      0.336325
# 4    -1.008243      -0.443219 -0.948728   -0.649090 -1.186814      0.336325
# ...        ...            ...       ...         ...       ...           ...
# 4502  0.991824      -0.443219  1.054043   -0.649090  0.115262      0.336325
# 4503 -1.008243      -0.443219  1.054043    1.540618  1.458029      0.336325
# 4504 -1.008243      -0.443219 -0.948728   -0.649090 -1.268194      0.336325
# 4505 -1.008243      -0.443219  1.054043   -0.649090 -1.186814     -2.973317
# 4506  0.991824      -0.443219  1.054043    1.540618  0.969750      0.336325
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  MultipleLines_No  ...  \
# 0             0.833665       -0.647670     -0.740576         -0.953806  ...
# 1            -1.199522       -1.512434     -0.377451          1.048431  ...
# 2             0.833665        0.978153      0.949639         -0.953806  ...
# 3            -1.199522        0.464647     -0.277473          1.048431  ...
# 4             0.833665       -1.520797     -0.974610          1.048431  ...
# ...                ...             ...           ...               ...  ...
# 4502         -1.199522       -0.269650     -0.180001          1.048431  ...
# 4503          0.833665        1.515075      2.306196         -0.953806  ...
# 4504         -1.199522       -1.492362     -0.996317          1.048431  ...
# 4505         -1.199522       -1.335132     -0.970619         -0.953806  ...
# 4506         -1.199522        0.802524      1.197775          1.048431  ...
#
#       StreamingMovies_No  StreamingMovies_No internet service  \
# 0               1.224066                            -0.515073
# 1              -0.816950                             1.941472
# 2              -0.816950                            -0.515073
# 3               1.224066                            -0.515073
# 4              -0.816950                             1.941472
# ...                  ...                                  ...
# 4502            1.224066                            -0.515073
# 4503           -0.816950                            -0.515073
# 4504           -0.816950                             1.941472
# 4505            1.224066                            -0.515073
# 4506           -0.816950                            -0.515073
#
#       StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 0               -0.799691                 0.883583          -0.505057
# 1               -0.799691                -1.131755          -0.505057
# 2                1.250483                -1.131755           1.979976
# 3               -0.799691                 0.883583          -0.505057
# 4               -0.799691                -1.131755           1.979976
# ...                   ...                      ...                ...
# 4502            -0.799691                 0.883583          -0.505057
# 4503             1.250483                -1.131755          -0.505057
# 4504            -0.799691                 0.883583          -0.505057
# 4505            -0.799691                 0.883583          -0.505057
# 4506             1.250483                -1.131755           1.979976
#
#       Contract_Two year  PaymentMethod_Bank transfer (automatic)  \
# 0             -0.554539                                -0.526777
# 1              1.803299                                -0.526777
# 2             -0.554539                                -0.526777
# 3             -0.554539                                -0.526777
# 4             -0.554539                                -0.526777
# ...                 ...                                      ...
# 4502          -0.554539                                -0.526777
# 4503           1.803299                                -0.526777
# 4504          -0.554539                                -0.526777
# 4505          -0.554539                                -0.526777
# 4506          -0.554539                                 1.898335
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  1.933707                       -0.719381
# 1                                  1.933707                       -0.719381
# 2                                 -0.517141                        1.390085
# 3                                 -0.517141                        1.390085
# 4                                 -0.517141                       -0.719381
# ...                                     ...                             ...
# 4502                              -0.517141                        1.390085
# 4503                              -0.517141                        1.390085
# 4504                              -0.517141                       -0.719381
# 4505                              -0.517141                       -0.719381
# 4506                              -0.517141                       -0.719381
#
#       PaymentMethod_Mailed check
# 0                      -0.547696
# 1                      -0.547696
# 2                      -0.547696
# 3                      -0.547696
# 4                       1.825830
# ...                          ...
# 4502                   -0.547696
# 4503                   -0.547696
# 4504                    1.825830
# 4505                    1.825830
# 4506                   -0.547696
#
# [4507 rows x 40 columns]

# %%
X_train_scaled_cols = X_train.copy()
numeric_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']
X_train_scaled_cols[numeric_cols] = scaler.fit_transform(X_train_scaled_cols[numeric_cols])
X_train_scaled_cols
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 544        0              0        0           0 -0.779915             0
# 1843       1              0        1           1  1.580098             1
# 3368       1              0        0           0  0.562851             1
# 5035       0              0        0           0 -0.495086             1
# 2750       0              0        0           0 -1.186814             1
# ...      ...            ...      ...         ...       ...           ...
# 6387       1              0        1           0  0.115262             1
# 4246       0              0        1           1  1.458029             1
# 6499       0              0        0           0 -1.268194             1
# 5631       0              0        1           0 -1.186814             0
# 3948       1              0        1           1  0.969750             1
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  MultipleLines_No  ...  \
# 544                  1       -0.647670     -0.740576                 0  ...
# 1843                 0       -1.512434     -0.377451                 1  ...
# 3368                 1        0.978153      0.949639                 0  ...
# 5035                 0        0.464647     -0.277473                 1  ...
# 2750                 1       -1.520797     -0.974610                 1  ...
# ...                ...             ...           ...               ...  ...
# 6387                 0       -0.269650     -0.180001                 1  ...
# 4246                 1        1.515075      2.306196                 0  ...
# 6499                 0       -1.492362     -0.996317                 1  ...
# 5631                 0       -1.335132     -0.970619                 0  ...
# 3948                 0        0.802524      1.197775                 1  ...
#
#       StreamingMovies_No  StreamingMovies_No internet service  \
# 544                    1                                    0
# 1843                   0                                    1
# 3368                   0                                    0
# 5035                   1                                    0
# 2750                   0                                    1
# ...                  ...                                  ...
# 6387                   1                                    0
# 4246                   0                                    0
# 6499                   0                                    1
# 5631                   1                                    0
# 3948                   0                                    0
#
#       StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 544                     0                        1                  0
# 1843                    0                        0                  0
# 3368                    1                        0                  1
# 5035                    0                        1                  0
# 2750                    0                        0                  1
# ...                   ...                      ...                ...
# 6387                    0                        1                  0
# 4246                    1                        0                  0
# 6499                    0                        1                  0
# 5631                    0                        1                  0
# 3948                    1                        0                  1
#
#       Contract_Two year  PaymentMethod_Bank transfer (automatic)  \
# 544                   0                                        0
# 1843                  1                                        0
# 3368                  0                                        0
# 5035                  0                                        0
# 2750                  0                                        0
# ...                 ...                                      ...
# 6387                  0                                        0
# 4246                  1                                        0
# 6499                  0                                        0
# 5631                  0                                        0
# 3948                  0                                        1
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 544                                       1                               0
# 1843                                      1                               0
# 3368                                      0                               1
# 5035                                      0                               1
# 2750                                      0                               0
# ...                                     ...                             ...
# 6387                                      0                               1
# 4246                                      0                               1
# 6499                                      0                               0
# 5631                                      0                               0
# 3948                                      0                               0
#
#       PaymentMethod_Mailed check
# 544                            0
# 1843                           0
# 3368                           0
# 5035                           0
# 2750                           1
# ...                          ...
# 6387                           0
# 4246                           0
# 6499                           1
# 5631                           1
# 3948                           0
#
# [4507 rows x 40 columns]

# %%
from preprocessingTelco import preprocessAndSplit
df = pd.read_csv(datadir+filename)
X_train, X_test, y_train, y_test = preprocessAndSplit(df)
X_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 6056       1              0        0           0  1.034513             1
# 2949       1              0        0           0  0.953134             1
# 5208       1              0        1           1 -0.755825             1
# 2483       0              1        1           1  0.546239             1
# 1023       1              1        1           0  0.505550             1
# ...      ...            ...      ...         ...       ...           ...
# 3948       1              0        1           1  0.953134             1
# 3496       0              0        0           0 -0.308241             1
# 5509       1              0        0           1 -1.122031             1
# 3183       0              1        1           0 -1.203410             0
# 6703       1              0        0           0 -1.244100             0
#
#       PaperlessBilling  MonthlyCharges  TotalCharges  MultipleLines_No  ...  \
# 6056                 1        0.210999      0.884968                 0  ...
# 2949                 1       -0.149398      0.436795                 1  ...
# 5208                 0       -0.175971     -0.666340                 1  ...
# 2483                 1        1.194201      0.991670                 0  ...
# 1023                 1        0.709243      0.691955                 1  ...
# ...                ...             ...           ...               ...  ...
# 3948                 0        0.802249      1.179854                 1  ...
# 3496                 0        0.317291     -0.149847                 1  ...
# 5509                 0       -0.622730     -0.912879                 1  ...
# 3183                 1       -0.939945     -0.969317                 0  ...
# 6703                 1       -0.647642     -0.972933                 0  ...
#
#       StreamingMovies_No  StreamingMovies_No internet service  \
# 6056                   1                                    0
# 2949                   1                                    0
# 5208                   1                                    0
# 2483                   1                                    0
# 1023                   0                                    0
# ...                  ...                                  ...
# 3948                   0                                    0
# 3496                   1                                    0
# 5509                   1                                    0
# 3183                   1                                    0
# 6703                   0                                    0
#
#       StreamingMovies_Yes  Contract_Month-to-month  Contract_One year  \
# 6056                    0                        0                  1
# 2949                    0                        0                  1
# 5208                    0                        1                  0
# 2483                    0                        1                  0
# 1023                    1                        1                  0
# ...                   ...                      ...                ...
# 3948                    1                        0                  1
# 3496                    0                        1                  0
# 5509                    0                        1                  0
# 3183                    0                        1                  0
# 6703                    1                        1                  0
#
#       Contract_Two year  PaymentMethod_Bank transfer (automatic)  \
# 6056                  0                                        0
# 2949                  0                                        0
# 5208                  0                                        1
# 2483                  0                                        0
# 1023                  0                                        0
# ...                 ...                                      ...
# 3948                  0                                        1
# 3496                  0                                        1
# 5509                  0                                        0
# 3183                  0                                        0
# 6703                  0                                        0
#
#       PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 6056                                      1                               0
# 2949                                      1                               0
# 5208                                      0                               0
# 2483                                      0                               1
# 1023                                      0                               1
# ...                                     ...                             ...
# 3948                                      0                               0
# 3496                                      0                               0
# 5509                                      0                               0
# 3183                                      0                               0
# 6703                                      0                               1
#
#       PaymentMethod_Mailed check
# 6056                           0
# 2949                           0
# 5208                           0
# 2483                           0
# 1023                           0
# ...                          ...
# 3948                           0
# 3496                           0
# 5509                           1
# 3183                           1
# 6703                           0
#
# [5634 rows x 40 columns]
